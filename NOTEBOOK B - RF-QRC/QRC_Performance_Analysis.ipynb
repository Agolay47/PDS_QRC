# %%
import QRC_construction.Performances as Perf
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ---
# ---
#
# # 4. Performance Analysis
#
# Here we compare the results obtained on the different datasets.
#
# ---
# ---

# %% [markdown]
# - reservoir accuracy overall
# - reservoir accuracy G1, G2, G3 in function of the depth
#
# - measurement basis choice overall
#
# - making the window size vary; what are the most sensitive datasets
#
# - changing traing and test sets sizes
#
# - adding extra qubits

# %%
file_narma3_all = "datas/Classical_Datasets/narma/All/train_2000_test10_3.txt"
file_tomato_all = "datas/Classical_Datasets/tomato/All/train_2000_test10.txt"
file_ham_all = "datas/Quantum_Datasets/All/Hamiltonians/Time-Dep1/datas_xyz.txt"

file_narma3_g = "datas/Classical_Datasets/narma/G/3B.txt"
file_narma5_g = "datas/Classical_Datasets/narma/G/5B.txt"

file_tomato_g = "datas/Classical_Datasets/tomato/G/dailyA.txt"

file_ham_g = "datas/Quantum_Datasets/G/HC.txt"

# %% [markdown]
# ## 4.1. Verifying Majorization Criterion, Optimal Measurement Basis, and extra qubits

# %% [markdown]
# ### 4.1.1. NARMA3

# %%
print("NARMA3 - Families - Best NRMSE:")

rows_best = Perf.table_classification_with_witness(
    file_narma3_all,
    param="family",
    tri="best",
)
i = 1
for r in rows_best:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})")
    i+=1

print("---------------------------------")
print("NARMA3 - Families - Average NRMSE:")
rows_avg = Perf.table_classification_with_witness(
    file_narma3_all,
    param="family",
    tri="avg",
)
i = 1
for r in rows_avg:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f})")
    i+=1
print("---------------------------------")
print("NARMA3 - Families - Worst NRMSE:")
rows_worst = Perf.table_classification_with_witness(
    file_narma3_all,
    param="family",
    tri="worst",
)
i = 1
for r in rows_worst:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})") 
    i+=1
# Out:
# NARMA3 - Families - Best NRMSE:
# 1) G3 (NRMSE=1.015, depth=10)
# 2) MG (NRMSE=1.149, depth=10)
# 3) ISING (NRMSE=1.175, ising=(10.0, 1, 0.1, 1.0))
# 4) D (NRMSE=1.236, k=3)
# 5) G1 (NRMSE=1.251, depth=3)
# 6) G2 (NRMSE=1.251, depth=10)
# ---------------------------------
# NARMA3 - Families - Average NRMSE:
# 1) MG (NRMSE=1.597)
# 2) ISING (NRMSE=1.659)
# 3) D (NRMSE=1.695)
# 4) G3 (NRMSE=2.013)
# 5) G2 (NRMSE=2.046)
# 6) G1 (NRMSE=2.218)
# ---------------------------------
# NARMA3 - Families - Worst NRMSE:
# 1) MG (NRMSE=3.414, depth=3)
# 2) ISING (NRMSE=4.806, ising=(10.0, 1, 0.1, 1.0))
# 3) D (NRMSE=4.897, k=2)
# 4) G1 (NRMSE=4.988, depth=3)
# 5) G2 (NRMSE=5.108, depth=10)
# 6) G3 (NRMSE=22.664, depth=10)

# %%
print("NARMA3 - Measurement Basis - Best NRMSE:")

rows_best = Perf.table_classification_with_witness(
    file_narma3_all,
    param="meas",
    tri="best",
)
i = 1
for r in rows_best:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})")
    i+=1

print("---------------------------------")
print("NARMA3 - Measurement Basis - Average NRMSE:")
rows_avg = Perf.table_classification_with_witness(
    file_narma3_all,
    param="meas",
    tri="avg",
)
i = 1
for r in rows_avg:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f})")
    i+=1
print("---------------------------------")
print("NARMA3 - Measurement Basis - Worst NRMSE:")
rows_worst = Perf.table_classification_with_witness(
    file_narma3_all,
    param="meas",
    tri="worst",
)
i = 1
for r in rows_worst:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})") 
    i+=1
# Out:
# NARMA3 - Measurement Basis - Best NRMSE:
# 1) S:Y (NRMSE=1.015, depth=10)
# 2) S:XZ (NRMSE=1.149, depth=10)
# 3) S+P:Y (NRMSE=1.184, ising=(10.0, 2, 0.1, 1.0))
# 4) S:XYZ (NRMSE=1.231, depth=3)
# 5) S+P:XZ (NRMSE=1.244, ising=(10.0, 1, 0.1, 1.0))
# 6) S+P:XYZ (NRMSE=1.251, depth=3)
# ---------------------------------
# NARMA3 - Measurement Basis - Average NRMSE:
# 1) S+P:XZ (NRMSE=1.463)
# 2) S+P:XYZ (NRMSE=1.498)
# 3) S:XYZ (NRMSE=1.672)
# 4) S:XZ (NRMSE=1.806)
# 5) S+P:Y (NRMSE=2.143)
# 6) S:Y (NRMSE=2.605)
# ---------------------------------
# NARMA3 - Measurement Basis - Worst NRMSE:
# 1) S+P:XZ (NRMSE=2.328, depth=10)
# 2) S:XZ (NRMSE=3.098, depth=10)
# 3) S:XYZ (NRMSE=3.485, depth=10)
# 4) S+P:Y (NRMSE=5.853, depth=10)
# 5) S:Y (NRMSE=6.835, depth=10)
# 6) S+P:XYZ (NRMSE=22.664, depth=10)

# %%
print("NARMA3 - Extra qubits - Best NRMSE:")

rows_best = Perf.table_classification_with_witness(
    file_narma3_all,
    param="extra",
    tri="best",
)
i = 1
for r in rows_best:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})")
    i+=1

print("---------------------------------")
print("NARMA3 - Extra qubits - Average NRMSE:")
rows_avg = Perf.table_classification_with_witness(
    file_narma3_all,
    param="extra",
    tri="avg",
)
i = 1
for r in rows_avg:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f})")
    i+=1
print("---------------------------------")
print("NARMA3 - Extra qubits - Worst NRMSE:")
rows_worst = Perf.table_classification_with_witness(
    file_narma3_all,
    param="extra",
    tri="worst",
)
i = 1
for r in rows_worst:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})") 
    i+=1
# Out:
# NARMA3 - Extra qubits - Best NRMSE:
# 1) 1 (NRMSE=1.015, depth=10)
# 2) 0 (NRMSE=1.149, depth=10)
# ---------------------------------
# NARMA3 - Extra qubits - Average NRMSE:
# 1) 1 (NRMSE=1.760)
# 2) 0 (NRMSE=1.972)
# ---------------------------------
# NARMA3 - Extra qubits - Worst NRMSE:
# 1) 1 (NRMSE=6.835, depth=10)
# 2) 0 (NRMSE=22.664, depth=10)

# %% [markdown]
# ### 4.1.2. Tomato daily price

# %%
print("Tomato Daily Price - Families - Best NRMSE:")

rows_best = Perf.table_classification_with_witness(
    file_tomato_all,
    param="family",
    tri="best",
)
i = 1
for r in rows_best:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})")
    i+=1

print("---------------------------------")
print("Tomato Daily Price - Families - Average NRMSE:")
rows_avg = Perf.table_classification_with_witness(
    file_tomato_all,
    param="family",
    tri="avg",
)
i = 1
for r in rows_avg:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f})")
    i+=1
print("---------------------------------")
print("Tomato Daily Price - Families - Worst NRMSE:")
rows_worst = Perf.table_classification_with_witness(
    file_tomato_all,
    param="family",
    tri="worst",
)
i = 1
for r in rows_worst:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})") 
    i+=1
# Out:
# Tomato Daily Price - Families - Best NRMSE:
# 1) D (NRMSE=0.954, k=3)
# 2) ISING (NRMSE=0.990, ising=(10.0, 2, 0.1, 1.0))
# 3) MG (NRMSE=1.012, depth=10)
# 4) G3 (NRMSE=1.052, depth=10)
# 5) G2 (NRMSE=1.054, depth=10)
# 6) G1 (NRMSE=1.067, depth=3)
# ---------------------------------
# Tomato Daily Price - Families - Average NRMSE:
# 1) MG (NRMSE=1.411)
# 2) ISING (NRMSE=1.710)
# 3) G3 (NRMSE=2.127)
# 4) G2 (NRMSE=2.398)
# 5) D (NRMSE=2.693)
# 6) G1 (NRMSE=2.868)
# ---------------------------------
# Tomato Daily Price - Families - Worst NRMSE:
# 1) MG (NRMSE=5.148, depth=10)
# 2) ISING (NRMSE=11.574, ising=(10.0, 1, 0.1, 1.0))
# 3) G3 (NRMSE=15.620, depth=10)
# 4) G1 (NRMSE=22.187, depth=10)
# 5) G2 (NRMSE=29.314, depth=10)
# 6) D (NRMSE=45.331, k=3)

# %%
print("Tomato Daily Price - Measurement Basis - Best NRMSE:")

rows_best = Perf.table_classification_with_witness(
    file_tomato_all,
    param="meas",
    tri="best",
)
i = 1
for r in rows_best:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})")
    i+=1

print("---------------------------------")
print("Tomato Daily Price - Measurement Basis - Average NRMSE:")
rows_avg = Perf.table_classification_with_witness(
    file_tomato_all,
    param="meas",
    tri="avg",
)
i = 1
for r in rows_avg:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f})")
    i+=1
print("---------------------------------")
print("Tomato Daily Price - Measurement Basis - Worst NRMSE:")
rows_worst = Perf.table_classification_with_witness(
    file_tomato_all,
    param="meas",
    tri="worst",
)
i = 1
for r in rows_worst:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})") 
    i+=1
# Out:
# Tomato Daily Price - Measurement Basis - Best NRMSE:
# 1) S:Y (NRMSE=0.954, k=3)
# 2) S:XZ (NRMSE=0.989, k=3)
# 3) S:XYZ (NRMSE=0.990, ising=(10.0, 2, 0.1, 1.0))
# 4) S+P:Y (NRMSE=0.998, k=2)
# 5) S+P:XZ (NRMSE=1.050, ising=(10.0, 1, 0.1, 1.0))
# 6) S+P:XYZ (NRMSE=1.054, depth=10)
# ---------------------------------
# Tomato Daily Price - Measurement Basis - Average NRMSE:
# 1) S+P:XYZ (NRMSE=1.255)
# 2) S+P:XZ (NRMSE=1.294)
# 3) S:XYZ (NRMSE=1.732)
# 4) S:XZ (NRMSE=1.917)
# 5) S+P:Y (NRMSE=3.367)
# 6) S:Y (NRMSE=3.790)
# ---------------------------------
# Tomato Daily Price - Measurement Basis - Worst NRMSE:
# 1) S+P:XYZ (NRMSE=2.079, depth=10)
# 2) S+P:XZ (NRMSE=2.885, depth=10)
# 3) S:Y (NRMSE=15.620, depth=10)
# 4) S:XYZ (NRMSE=22.187, depth=10)
# 5) S:XZ (NRMSE=29.314, depth=10)
# 6) S+P:Y (NRMSE=45.331, k=3)

# %%
print("Tomato Daily Price - Extra qubits - Best NRMSE:")

rows_best = Perf.table_classification_with_witness(
    file_tomato_all,
    param="extra",
    tri="best",
)
i = 1
for r in rows_best:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})")
    i+=1

print("---------------------------------")
print("Tomato Daily Price - Extra qubits - Average NRMSE:")
rows_avg = Perf.table_classification_with_witness(
    file_tomato_all,
    param="extra",
    tri="avg",
)
i = 1
for r in rows_avg:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f})")
    i+=1
print("---------------------------------")
print("Tomato Daily Price - Extra qubits - Worst NRMSE:")
rows_worst = Perf.table_classification_with_witness(
    file_tomato_all,
    param="extra",
    tri="worst",
)
i = 1
for r in rows_worst:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})") 
    i+=1
# Out:
# Tomato Daily Price - Extra qubits - Best NRMSE:
# 1) 1 (NRMSE=0.954, k=3)
# 2) 0 (NRMSE=0.990, ising=(10.0, 2, 0.1, 1.0))
# ---------------------------------
# Tomato Daily Price - Extra qubits - Average NRMSE:
# 1) 1 (NRMSE=1.821)
# 2) 0 (NRMSE=2.638)
# ---------------------------------
# Tomato Daily Price - Extra qubits - Worst NRMSE:
# 1) 1 (NRMSE=15.620, depth=10)
# 2) 0 (NRMSE=45.331, k=3)

# %% [markdown]
# ### 4.1.3. Time-Dependent single-qubit Hamiltonian

# %%
print("Time-Dep Ham. - Families - Best NRMSE:")

rows_best = Perf.table_classification_with_witness(
    file_ham_all,
    param="family",
    tri="best",
)
i = 1
for r in rows_best:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})")
    i+=1

print("---------------------------------")
print("Time-Dep Ham. - Families - Average NRMSE:")
rows_avg = Perf.table_classification_with_witness(
    file_ham_all,
    param="family",
    tri="avg",
)
i = 1
for r in rows_avg:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f})")
    i+=1
print("---------------------------------")
print("Time-Dep Ham. - Families - Worst NRMSE:")
rows_worst = Perf.table_classification_with_witness(
    file_ham_all,
    param="family",
    tri="worst",
)
i = 1
for r in rows_worst:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})") 
    i+=1
# Out:
# Time-Dep Ham. - Families - Best NRMSE:
# 1) D (NRMSE=0.176, k=5)
# 2) ISING (NRMSE=0.307, ising=(10.0, 2, 0.1, 1.0))
# 3) MG (NRMSE=0.577, depth=3)
# 4) G3 (NRMSE=1.037, depth=3)
# 5) G2 (NRMSE=1.376, depth=3)
# 6) G1 (NRMSE=1.548, depth=3)
# ---------------------------------
# Time-Dep Ham. - Families - Average NRMSE:
# 1) G3 (NRMSE=12.516)
# 2) MG (NRMSE=12.838)
# 3) G2 (NRMSE=13.100)
# 4) G1 (NRMSE=14.688)
# 5) ISING (NRMSE=23.776)
# 6) D (NRMSE=43.812)
# ---------------------------------
# Time-Dep Ham. - Families - Worst NRMSE:
# 1) G1 (NRMSE=180.805, depth=3)
# 2) G2 (NRMSE=180.805, depth=3)
# 3) G3 (NRMSE=180.805, depth=3)
# 4) MG (NRMSE=377.051, depth=10)
# 5) ISING (NRMSE=377.051, ising=(10.0, 2, 0.1, 1.0))
# 6) D (NRMSE=430.510, k=4)

# %%
print("Time-Dep Ham. - Measurement Basis - Best NRMSE:")

rows_best = Perf.table_classification_with_witness(
    file_ham_all,
    param="meas",
    tri="best",
)
i = 1
for r in rows_best:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})")
    i+=1

print("---------------------------------")
print("Time-Dep Ham. - Measurement Basis - Average NRMSE:")
rows_avg = Perf.table_classification_with_witness(
    file_ham_all,
    param="meas",
    tri="avg",
)
i = 1
for r in rows_avg:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f})")
    i+=1
print("---------------------------------")
print("Time-Dep Ham. - Measurement Basis - Worst NRMSE:")
rows_worst = Perf.table_classification_with_witness(
    file_ham_all,
    param="meas",
    tri="worst",
)
i = 1
for r in rows_worst:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})") 
    i+=1
# Out:
# Time-Dep Ham. - Measurement Basis - Best NRMSE:
# 1) S+P:XYZ (NRMSE=0.176, k=5)
# 2) S+P:XZ (NRMSE=0.577, depth=3)
# 3) S:XYZ (NRMSE=0.686, depth=10)
# 4) S+P:Y (NRMSE=0.820, ising=(10.0, 2, 0.1, 1.0))
# 5) S:XZ (NRMSE=1.242, depth=10)
# 6) S:Y (NRMSE=2.029, depth=10)
# ---------------------------------
# Time-Dep Ham. - Measurement Basis - Average NRMSE:
# 1) S+P:Y (NRMSE=9.713)
# 2) S:Y (NRMSE=10.675)
# 3) S:XZ (NRMSE=11.157)
# 4) S+P:XZ (NRMSE=14.792)
# 5) S:XYZ (NRMSE=23.483)
# 6) S+P:XYZ (NRMSE=56.596)
# ---------------------------------
# Time-Dep Ham. - Measurement Basis - Worst NRMSE:
# 1) S:Y (NRMSE=19.930, k=2)
# 2) S+P:Y (NRMSE=41.019, k=3)
# 3) S:XZ (NRMSE=67.959, k=3)
# 4) S:XYZ (NRMSE=348.955, k=3)
# 5) S+P:XZ (NRMSE=377.051, ising=(10.0, 2, 0.1, 1.0))
# 6) S+P:XYZ (NRMSE=430.510, k=4)

# %%
print("Time-Dep Ham. - Extra qubits - Best NRMSE:")

rows_best = Perf.table_classification_with_witness(
    file_ham_all,
    param="extra",
    tri="best",
)
i = 1
for r in rows_best:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})")
    i+=1

print("---------------------------------")
print("Time-Dep Ham. - Extra qubits - Average NRMSE:")
rows_avg = Perf.table_classification_with_witness(
    file_ham_all,
    param="extra",
    tri="avg",
)
i = 1
for r in rows_avg:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f})")
    i+=1
print("---------------------------------")
print("Time-Dep Ham. - Extra qubits - Worst NRMSE:")
rows_worst = Perf.table_classification_with_witness(
    file_ham_all,
    param="extra",
    tri="worst",
)
i = 1
for r in rows_worst:
    w = r["witness"]
    print(f"{i}) {r['value']} (NRMSE={r['NRMSE']:.3f}, {w['param_name']}={w['param_val']})") 
    i+=1
# Out:
# Time-Dep Ham. - Extra qubits - Best NRMSE:
# 1) 2 (NRMSE=0.176, k=5)
# 2) 1 (NRMSE=0.485, ising=(10.0, 1, 0.1, 1.0))
# 3) 0 (NRMSE=1.037, depth=3)
# ---------------------------------
# Time-Dep Ham. - Extra qubits - Average NRMSE:
# 1) 0 (NRMSE=15.395)
# 2) 1 (NRMSE=18.941)
# 3) 2 (NRMSE=28.354)
# ---------------------------------
# Time-Dep Ham. - Extra qubits - Worst NRMSE:
# 1) 0 (NRMSE=348.955, k=3)
# 2) 1 (NRMSE=424.058, k=2)
# 3) 2 (NRMSE=430.510, k=4)

# %% [markdown]
# ## 4.2. Sliding window size

# %% [markdown]
# ### 4.2.1 NARMA3 and NARMA5

# %%
fig, ax = Perf.graph_classification(
    [file_narma3_g, file_narma5_g],
    x_param="n",
    tri="avg",
    labels=["NARMA3", "NARMA5"],
)
ax.set_title("NRMSE vs window size on NARMA tasks")
#ax.set_ylim(0, 3)
#ax.axvline(3, linestyle="--", color="k", label="expected optimal window size for NARMA3", alpha=0.6)
#ax.axvline(5, linestyle="--", color="k", label="expected optimal n for NARMA5", alpha=0.6)
plt.legend()
fig.set_size_inches(10, 3)

plt.show()

# %% [markdown]
# ## 4.3. Depth vs NRMSE

# %%
fig, axes = Perf.plot_metric_vs_depth_G1G2G3_pooled(
    [file_narma3_g, file_narma5_g, file_tomato_g, file_ham_g, file_narma3_all, file_tomato_all, file_ham_all],
    metric="NRMSE",
    avg_mode="topk",
    top_k=10,
    curve_label="pooled top-10 mean (all datasets)",
)
plt.show()

# %% [markdown]
# ## 4.4. Depth vs Complexity

# %%
fig, axes = Perf.plot_metric_vs_depth_G1G2G3_pooled(
    [file_narma3_g, file_narma5_g, file_tomato_g, file_ham_g, file_narma3_all, file_tomato_all, file_ham_all],
    metric="time",
    curve_label="pooled top-10 mean (all datasets)",
)
plt.show()

# %% [markdown]
# # 4.5. Encoding Basis Analysis

# %%
ranked = Perf.correlation_encoding_measurement(
    [file_narma3_g],
)

for i, r in enumerate(ranked, 1):
    print(f"{i}) {r['encoding']} & {r['meas_axis']}: "
          f"mean NRMSE={r['mean_NRMSE']:.3f}")
# Out:
# 1) Rz & Z: mean NRMSE=1.478
# 2) Ry & Z: mean NRMSE=1.958
# 3) Ry & Y: mean NRMSE=2.881
# 4) Rz & Y: mean NRMSE=3.393

# %%
ranked = Perf.correlation_encoding_measurement(
    [file_narma5_g],
)

for i, r in enumerate(ranked, 1):
    print(f"{i}) {r['encoding']} & {r['meas_axis']}: "
          f"mean NRMSE={r['mean_NRMSE']:.3f}")
# Out:
# 1) Rz & Z: mean NRMSE=1.017
# 2) Ry & Z: mean NRMSE=1.077
# 3) Ry & Y: mean NRMSE=2.266
# 4) Rz & Y: mean NRMSE=3.380

# %%
ranked = Perf.correlation_encoding_measurement(
    [file_tomato_g],
)

for i, r in enumerate(ranked, 1):
    print(f"{i}) {r['encoding']} & {r['meas_axis']}: "
          f"mean NRMSE={r['mean_NRMSE']:.3f}")
# Out:
# 1) Rz & Z: mean NRMSE=1.122
# 2) Ry & Z: mean NRMSE=1.888
# 3) Ry & Y: mean NRMSE=3.422
# 4) Rz & Y: mean NRMSE=6.087
